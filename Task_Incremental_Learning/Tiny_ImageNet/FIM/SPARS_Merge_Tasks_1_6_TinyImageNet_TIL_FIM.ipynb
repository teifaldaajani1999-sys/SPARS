# %%
# === Merge (SUM) without any cap; remove overlap Neighbors-TopK ===
import pickle
from collections import defaultdict
from google.colab import drive

# === 0. Mount Google Drive ===
drive.mount('/content/drive')
topk_paths = [
    "/content/drive/MyDrive/ML_Project/project_files/First_benchmark/groupNorm_fisher_task1_2_3_4_5_tiny_imageNet_topk_temp2.pkl",
    "/content/drive/MyDrive/ML_Project/project_files/First_benchmark/expriment2_GN_task6F_tiny_imageNet_topk_temp2.pkl",
]
neigh_paths = [
    "/content/drive/MyDrive/ML_Project/project_files/First_benchmark/groupNorm_fisher_task1_2_3_4_5_tiny_imageNet_neighbors_temp2.pkl",
    "/content/drive/MyDrive/ML_Project/project_files/First_benchmark/expriment2_GN_task6F_tiny_imageNet_neighbors_temp2.pkl",
]

out_topk_path  = "/content/drive/MyDrive/ML_Project/project_files/First_benchmark/groupNorm_fisher_task1_2_3_4_5_6_tiny_imageNet_topk_temp2.pkl"
out_neigh_path = "/content/drive/MyDrive/ML_Project/project_files/First_benchmark/groupNorm_fisher_task1_2_3_4_5_6_tiny_imageNet_neighbors_temp2.pkl"

def load_list(p):
    with open(p, "rb") as f:
        return pickle.load(f)

# 1) Union of Top-K (sum Fisher values if present)
topk_union = defaultdict(lambda: {"name": None, "index": None, "fisher": 0.0})
for p in topk_paths:
    for e in load_list(p):
        key = (e["name"], int(e["index"]))
        if topk_union[key]["name"] is None:
            topk_union[key]["name"]  = e["name"]
            topk_union[key]["index"] = int(e["index"])
        topk_union[key]["fisher"] += float(e.get("fisher", 0.0))

topk_merged = list(topk_union.values())
topk_keys   = {(d["name"], d["index"]) for d in topk_merged}

# 2) Union of Neighbors (sum) while excluding Top-K to prevent overlap
neigh_union = defaultdict(lambda: {"name": None, "index": None, "position": (), "fisher": 0.0})
for p in neigh_paths:
    for it in load_list(p):
        key = (it["name"], int(it["index"]))
        if key in topk_keys:
            continue  # Prevent overlap: a parameter cannot be both a neighbor and frozen
        if neigh_union[key]["name"] is None:
            neigh_union[key]["name"]  = it["name"]
            neigh_union[key]["index"] = int(it["index"])
            if "position" in it:
                neigh_union[key]["position"] = tuple(it["position"])
        neigh_union[key]["fisher"] += float(it.get("fisher", 0.0))

neighbors_merged = list(neigh_union.values())

# 3) Final check (must be 0)
inter = sum(1 for n in neighbors_merged if (n["name"], n["index"]) in topk_keys)
print("Intersection(Neighbors, TopK) =", inter)

# 4) Save as is (without truncation/percentage)
with open(out_topk_path,  "wb") as f: pickle.dump(topk_merged, f)
with open(out_neigh_path, "wb") as f: pickle.dump(neighbors_merged, f)

print(f"TopK merged: {len(topk_merged)} | Neighbors merged: {len(neighbors_merged)}")
# Out:
# Mounted at /content/drive
# Intersection(Neighbors, TopK) = 0
# TopK merged: 1916407 | Neighbors merged: 853187
